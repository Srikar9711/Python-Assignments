# %% [markdown]
#  write a program to find the given string in the root directory that contains a text file 1. In a recursive manner (case in sensitive ) 2. only in the root directory use command line arguments. program_name -ri string root_dir (recursive) program_name -si string root_dir (root director ) The output which file and line contains the string

# %%
import os
root = "C:\\Users\dell\Desktop"
for root,dir,files in os.walk(root):
    for f in files:
        path=root+"\\"+f
        print(path)

def check_string_in_file(f, string_to_search):
    with open(file_name, 'r') as read_obj:
        for line in read_obj:
            if string_to_search in line:
                return True
    return False
    with open(f) as myFile:
        for num, line in enumerate(myFile, 1):
             if lookup in line:
                print('found at line:', num)
# Out:
# C:\Users\dell\Desktop\1.jpg
# C:\Users\dell\Desktop\15BD1A05CH-Acknowledgment.pdf
# C:\Users\dell\Desktop\2.jpg
# C:\Users\dell\Desktop\3.jpg
# C:\Users\dell\Desktop\4.jpg
# C:\Users\dell\Desktop\Admitcard _ Scholarships Exam.pdf
# C:\Users\dell\Desktop\Application Id_ 13101.pdf
# C:\Users\dell\Desktop\ass.php
# C:\Users\dell\Desktop\ass1.html
# C:\Users\dell\Desktop\Blog performance tracking.pptx
# C:\Users\dell\Desktop\coursera.pdf
# C:\Users\dell\Desktop\ctwtupdatedlabmanual.docx
# C:\Users\dell\Desktop\D0269.png.jpg
# C:\Users\dell\Desktop\desktop.ini
# C:\Users\dell\Desktop\documentation UML.docx
# C:\Users\dell\Desktop\E Campus - TechM.pdf
# C:\Users\dell\Desktop\Eclipse Jee Oxygen.lnk
# C:\Users\dell\Desktop\IRCTC Next Generation eTicketing System.pdf
# C:\Users\dell\Desktop\KMIT Campus 2017 Written test.docx
# C:\Users\dell\Desktop\LATEST CV.docx
# C:\Users\dell\Desktop\LP final manual.docx
# C:\Users\dell\Desktop\LRS Payment.pdf
# C:\Users\dell\Desktop\m.txt
# ...
